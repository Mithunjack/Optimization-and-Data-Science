# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import fft
import pandas as pd
from numpy import loadtxt
from scipy.spatial import distance


dax_data = np.loadtxt("dax_data.txt", comments="#", delimiter="\n")
plt.plot(dax_data)

coef_array = np.fft.fft(dax_data)
time_step = 1

sample_freq = fft.fftfreq(dax_data.size, d=time_step)
amplitude = np.abs(coef_array)
amp_freq = np.array([amplitude,sample_freq])

max_amp_position_array = np.argsort(amp_freq[0,:])[::-1]
peak_freq = amp_freq[1,max_amp_position_array[0]]


def approximation(num_coef):
    copy_coef = coef_array.copy()
    copy_coef[np.abs(sample_freq) > amp_freq[1,max_amp_position_array[num_coef-1]]]  = 0
    filtered_sig = np.fft.ifft(copy_coef)
    plt.plot(filtered_sig)
    
    
def average_difference(approximate_data):
    dist = distance.euclidean(dax_data , approximate_data)/dax_data.size
    return dist
    
def best_approximation(difference):
    counter = 0
    iteration = 0
    while counter < dax_data.size:
        copy_coef = coef_array.copy()
        copy_coef[np.abs(sample_freq) > amp_freq[1,max_amp_position_array[counter]]]  = 0
        filtered_data = np.fft.ifft(copy_coef)
        average = np.absolute(average_difference(filtered_data))
        if average > 1.95:
            counter += 1
        else:
            plt.plot(filtered_data)
            break
            
    print(counter)
    

# # #with 10 coeffecient
# high_freq_fft = coef_array.copy()
# high_freq_fft[np.abs(sample_freq) > amp_freq[1,max_amp_position_array[10]]]  = 0
# filtered_sig = np.fft.ifft(high_freq_fft)
# plt.plot(filtered_sig)

approximation(1)
approximation(5)
approximation(10)

best_approximation(100)

# a = [1,2,3] 
# b= [12,123,3,5]
# c = np.array([a,b])
# print(c[0])
# print(c[0][1])
# print(c)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 123
# [1, 2, 3]
# 2
# [list([1, 2, 3]) list([12, 123, 3, 5])]

# %%
def create_signal(num_sig):
    i = 1
    while i<=num_sig:
        n = 6940
        lx = 10
        omg = 2*np.pi/lx
        x = np.linspace(0,lx,n)
        amp = amp_freq[0][i]
        freq = 1/amp_freq[1][i]
        print(amp,freq)
        signal = amp*np.sin(omg*freq+x)
        plt.plot(freq,amp)
        i += 1

create_signal(5)
# Out:
# 11261531.878794253 6940.0
# 7096323.922045597 3470.0
# 4017156.2272280175 2313.3333333333335
# 1492448.9377927764 1735.0
# 2116783.948244769 1387.9999999999998

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b8da1678aaf2> in <module>
#       1 a = [1,2,3]
#       2 b= [12,123,3,5]
# ----> 3 print(np.array[a,b])
#
# NameError: name 'np' is not defined
